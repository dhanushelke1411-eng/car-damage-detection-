# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
zip_path = '/content/drive/MyDrive/archive.zip'

# %%
import zipfile

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('data')

print("Extracted ✅")
# Out:
# Extracted ✅

# %%
import os
os.listdir('data')
# Out:
# ['data1a']

# %%
os.listdir('data/data1a')
# Out:
# ['training', 'validation']

# %%
import tensorflow as tf

img_size = (224, 224)
batch_size = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    'data/data1a/training',
    image_size=img_size,
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    'data/data1a/validation',
    image_size=img_size,
    batch_size=batch_size
)

print("Classes:", train_ds.class_names)
# Out:
# Found 1840 files belonging to 2 classes.
# Found 460 files belonging to 2 classes.
# Classes: ['00-damage', '01-whole']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras import layers, models

base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

base_model.trainable = False

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
])
model = models.Sequential([
    data_augmentation,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=3,
    restore_best_weights=True
)

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'car_damage_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6288 - loss: 0.7726
# Epoch 1: val_accuracy improved from None to 0.71304, saving model to car_damage_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to car_damage_model.h5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.6658 - loss: 0.7193 - val_accuracy: 0.7130 - val_loss: 0.5332
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7324 - loss: 0.5924
# Epoch 2: val_accuracy did not improve from 0.71304
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - accuracy: 0.7380 - loss: 0.5792 - val_accuracy: 0.6804 - val_loss: 0.5412
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7324 - loss: 0.5453
# Epoch 3: val_accuracy improved from 0.71304 to 0.78261, saving model to car_damage_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to car_damage_model.h5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.7364 - loss: 0.5607 - val_accuracy: 0.7826 - val_loss: 0.4627
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7655 - loss: 0.5107
# Epoch 4: val_accuracy did not improve from 0.78261
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 140s 2s/step - accuracy: 0.7652 - loss: 0.5116 - val_accuracy: 0.7696 - val_loss: 0.4537
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7644 - loss: 0.5066
# Epoch 5: val_accuracy did not improve from 0.78261
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - accuracy: 0.7668 - loss: 0.4958 - val_accuracy: 0.7543 - val_loss: 0.4667
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7710 - loss: 0.4991
# Epoch 6: val_accuracy did not improve from 0.78261
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.7723 - loss: 0.5020 - val_accuracy: 0.7826 - val_loss: 0.4253
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7787 - loss: 0.4709
# Epoch 7: val_accuracy improved from 0.78261 to 0.80435, saving model to car_damage_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to car_damage_model.h5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 126s 2s/step - accuracy: 0.7783 - loss: 0.4790 - val_accuracy: 0.8043 - val_loss: 0.4284
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7883 - loss: 0.4725
# Epoch 8: val_accuracy did not improve from 0.80435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.7832 - loss: 0.4722 - val_accuracy: 0.7935 - val_loss: 0.4319
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8187 - loss: 0.4069
# Epoch 9: val_accuracy did not improve from 0.80435
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8087 - loss: 0.4284 - val_accuracy: 0.8043 - val_loss: 0.4433

# %%
val_loss, val_acc = model.evaluate(val_ds)
print("Validation Accuracy:", val_acc)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7826 - loss: 0.4253
# Validation Accuracy: 0.782608687877655
